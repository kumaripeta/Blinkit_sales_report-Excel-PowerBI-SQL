# %% [markdown]
# ### **DATA ANALYSIS PYTHON PROJECT-BLINKIT DATA**

# %% [markdown]
# ##### **Import libraries**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ##### **Blinkit-Python-Data**

# %%
d=pd.read_csv("C:\\Users\\91911\\OneDrive\\Data\\blinkit_data_python.csv")
d.head()
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2010            OUT046               Tier 1
# 3                       2000            OUT013               Tier 3
# 4                       2015            OUT045               Tier 2
#
#   Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 0      Medium  Supermarket Type1         0.100014        15.10  145.4786
# ...

# %% [markdown]
# ##### **Size of the data**

# %%
print("Size of the datad.shape",d.shape)
# Out:
# Size of the datad.shape (8523, 12)

# %% [markdown]
# ##### **Field information**

# %%
d.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %% [markdown]
# ##### **Data Types**

# %%
d.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %% [markdown]
# ##### **Data Cleaning**

# %%
d.head(10)
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
# 5          low fat           FDS52           Frozen Foods
# 6          Low Fat           NCU05     Health and Hygiene
# 7          Low Fat           NCD30              Household
# 8          Low Fat           FDW20  Fruits and Vegetables
# 9          Low Fat           FDX25                 Canned
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2010            OUT046               Tier 1
# ...

# %%
d['Item Fat Content'].unique()
# Out:
# array(['Regular', 'Low Fat', 'low fat', 'LF', 'reg'], dtype=object)

# %%
d['Item Fat Content']=d['Item Fat Content'].replace({'low fat':'Low Fat',
                             'LF':'Low Fat',
                             'reg':'Regular'})

# %%
d['Item Fat Content'].unique()
# Out:
# array(['Regular', 'Low Fat'], dtype=object)

# %% [markdown]
# ##### **KPI Requirements**

# %%
d
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 0             Regular           FDX32  Fruits and Vegetables
# 1             Low Fat           NCB42     Health and Hygiene
# 2             Regular           FDR28           Frozen Foods
# 3             Regular           FDL50                 Canned
# 4             Low Fat           DRI25            Soft Drinks
# ...               ...             ...                    ...
# 8518          Low Fat           NCT53     Health and Hygiene
# 8519          Low Fat           FDN09            Snack Foods
# 8520          Low Fat           DRE13            Soft Drinks
# 8521          Regular           FDT50                  Dairy
# 8522          Regular           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                          2012            OUT049               Tier 1
# 1                          2022            OUT018               Tier 3
# ...

# %%
# total sales
Total_Sales=d['Sales'].sum()
Total_Sales
# Avg sales
Avg_Sales=d['Sales'].mean()
Avg_Sales
# No Of Irems sold
No_Of_Items_Sold=d['Sales'].count()
No_Of_Items_Sold
#Avg Rating
Avg_Rating=d['Rating'].mean()
Avg_Rating
# Out:
# np.float64(3.965857092573038)

# %% [markdown]
# ##### **Charts Requirements**

# %% [markdown]
# ##### **Total Sales by fat content**

# %%
Total_Sales_fatcontent=d.groupby('Item Fat Content')['Sales'].sum()
plt.pie(Total_Sales_fatcontent,autopct="%.1f%%",labels=Total_Sales_fatcontent.index,shadow=True,explode=[0.2,0])
plt.title("Total_Sales_fatcontent")
plt.show()

# %%
d.head(2)
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
#
#   Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 0      Medium  Supermarket Type1         0.100014         15.1  145.4786
# 1      Medium  Supermarket Type2         0.008596         11.8  115.3492
#
#    Rating
# 0     5.0
# 1     5.0

# %%
Total_sales_fatcontent=d.groupby('Item Fat Content')['Sales'].sum()
dict={'family':'arial','size':16,'color':'green'}
plt.title("Sales by fatcontent",fontdict=dict)
plt.pie(Total_sales_fatcontent,labels=Total_sales_fatcontent.index,colors=['orange','green'],autopct='%1.1f%%',pctdistance=1.3,explode=[0,0.03])
plt.legend(Total_sales_fatcontent.index)
plt.show()

# %%
Sales_by_Itemtype=d.groupby('Item Type')['Sales'].sum()
plt.barh(Sales_by_Itemtype.index,Sales_by_Itemtype.values,color='orange')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### **Total Sales by ItemType**

# %%
Total_Sales_Itemtype=d.groupby('Item Type')['Sales'].sum()
plt.bar(Total_Sales_Itemtype.index,Total_Sales_Itemtype.values,width=0.8)
plt.title("Total_Sales_Itemtype")
plt.xticks(rotation=90)
plt.xlabel("Item Type")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ##### **fat content by outlet for total sales**

# %% [markdown]
# ##### **toatal sales by outlet Establishment**

# %%
d.head(2)
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
#
#   Outlet Size        Outlet Type  Item Visibility  Item Weight     Sales  \
# 0      Medium  Supermarket Type1         0.100014         15.1  145.4786
# 1      Medium  Supermarket Type2         0.008596         11.8  115.3492
#
#    Rating
# 0     5.0
# 1     5.0

# %%
d['Outlet Establishment Year'].unique()
# Out:
# array([2012, 2022, 2010, 2000, 2015, 2020, 2011, 1998, 2017])

# %%
Sales_by_outlet_establishment_year=d.groupby('Outlet Establishment Year')['Sales'].sum()
f2={
     'family':'arial',
    'size':16,
    'color':'blue'
}
plt.title('Sales by outlet establishment year',fontdict=f2)
plt.plot(Sales_by_outlet_establishment_year.index,Sales_by_outlet_establishment_year.values,marker='o',mfc='green',mec='red')

f1={
    'family':'arial',
    'size':10,
    'color':'green'
}

plt.xlabel('Sales',fontdict=f1)
plt.ylabel('Year',fontdict=f1)

plt.fill_between(
   Sales_by_outlet_establishment_year.index,
    Sales_by_outlet_establishment_year.values,
    color='orange',
    alpha=0.8
)
plt.show()

# %%
Sales_by_outlet_establishment_year=d.groupby('Outlet Establishment Year')['Sales'].sum()
f1={
    'family':'arial',
     'size':14,
    'color':'green'
}
f2={
     'family':'arial',
    'size':16,
    'color':'blue'
}
plt.title("Sales by outlet establishment year",fontdict=f1)
plt.xlabel('Year',fontdict=f2)
plt.ylabel('Sales',fontdict=f2)
plt.bar(Sales_by_outlet_establishment_year.index,Sales_by_outlet_establishment_year.values,color='orange',width=1.5)
plt.show()

# %%
Sales_by_outlet_location=d.groupby('Outlet Location Type')['Sales'].sum()
f1={
    'family':'arial',
    'size':17,
    'color':'green'
}
f2={
    'family':'arial',
    'size':14,
    'color':'orange'
}

plt.title('Sales by outlet location',fontdict=f1)
plt.xlabel('Location',fontdict=f2)
plt.ylabel('Sales',fontdict=f2)
plt.bar(Sales_by_outlet_location.index,Sales_by_outlet_location.values,width=0.4,color='yellow',edgecolor='green')
plt.show()

# %%
Sales_by_outlet_location=d.groupby('Outlet Location Type')['Sales'].sum()
f1={
    'family':'arial',
    'size':17,
    'color':'green'
}
f2={
    'family':'arial',
    'size':14,
    'color':'orange'
}

plt.title('Sales by outlet location',fontdict=f1)
plt.xlabel('Location',fontdict=f2)
plt.ylabel('Sales',fontdict=f2)
plt.barh(Sales_by_outlet_location.index,Sales_by_outlet_location.values,height=0.5,color='yellow',edgecolor='green')
plt.show()

# %%
Sales_by_outlet_location=d.groupby('Outlet Location Type')['Sales'].sum()
plt.figure(figsize=(10,5))
f1={
    'family':'arial',
    'color':'blue',
    'size':14
}
plt.title('Sales by outlet location',fontdict=f1)
plt.pie(Sales_by_outlet_location,labels=Sales_by_outlet_location.index,autopct='%1.1f%%',colors=['orange','yellow','green'],startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x26d884a4190>,
# ...
#  [Text(-0.8474306786545621, 0.7013282005417069, 'Tier 1'),
#   Text(-0.3822013688332541, -1.0314660021842634, 'Tier 2'),
#   Text(1.038313466794419, 0.3631874786847083, 'Tier 3')],
#  [Text(-0.46223491562976105, 0.382542654840931, '28.0%'),
#   Text(-0.20847347390904766, -0.5626178193732345, '32.7%'),
#   Text(0.5663528000696829, 0.19810226110074997, '39.3%')])

# %%
sales_by_outet_establishment=d.groupby('Outlet Establishment Year')['Sales'].sum()

# %%
Total_Sales_Outletestblaishment=df.groupby('Outlet Establishment Year')['Sales'].sum()
plt.plot(Total_Sales_Outletestblaishment.index,Total_Sales_Outletestblaishment.values,marker='o',mfc="yellow",mec='green',)
plt.fill_between(Total_Sales_Outletestblaishment.index,Total_Sales_Outletestblaishment.values,color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Total_Sales_Outletestblaishment=df.groupby('Outlet Establishment Year')['Sales'].sum()
#       2 plt.plot(Total_Sales_Outletestblaishment.index,Total_Sales_Outletestblaishment.values,marker='o',mfc="yellow",mec='green',)
#       3 plt.fill_between(Total_Sales_Outletestblaishment.index,Total_Sales_Outletestblaishment.values,color='red')
#
# NameError: name 'df' is not defined

# %%
Total_Sales_Outlet_Establishment=d.groupby("Outlet Establishment Year")['Sales'].sum()
plt.plot(Total_Sales_Outlet_Establishment.index,Total_Sales_Outlet_Establishment.values,marker="o",linestyle="-",mfc="Yellow",mec="red")
plt.title("Total_Sales_Outlet_Establishment")
plt.xlabel("establishment Year")
plt.ylabel("Total Sales")
plt.show()

# %%
Total_Sales_Outlet_Establishment=d.groupby("Outlet Establishment Year")['Sales'].sum()
plt.plot(Total_Sales_Outlet_Establishment.index,Total_Sales_Outlet_Establishment.values,marker="o",linestyle="-",mfc="Yellow",mec="red")
plt.title("Total_Sales_Outlet_Establishment")
plt.xlabel("establishment Year")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# ##### **Total sales by outlet size**

# %%
d.head(2)

# %%
Total_Sales_Outletsize=df.groupby('Outlet Size')['Sales'].sum()
plt.pie(Total_Sales_Outletsize,autopct='%.1f%%',wedgeprops={'width':0.5})
plt.legend(Total_Sales_Outletsize.index,fancybox=True,shadow=True,title="Details of the Pie chart")
plt.show()

# %%
Total_Sales_Outletsize=d.groupby('Outlet Size')["Sales"].sum()
plt.pie(Total_Sales_Outletsize,labels=Total_Sales_Outletsize.index,autopct="%.2f%%")
plt.title("Total_Sales_Outletsize")
plt.show()

# %% [markdown]
# ##### **Sales by outlet Location-hbar**

# %%
sal_outlet_location=d.groupby("Outlet Location Type")['Sales'].sum()
plt.barh(sal_outlet_location.index,sal_outlet_location.values,height=0.4)
plt.show()

# %%
grouped=d.groupby(['Outlet Location Type','Item Fat Content'])['Sales'].sum().unstack()
#grouped=grouped[['Regular','Low Fat']]
ax=grouped.plot(kind='bar',color=['#9acd32','#ffed29'])
f1={'family':'arial','size':15,'color':'orange'}
plt.title('Fat content by outlet for total sales',fontdict=f1)
f2={'family':'arial','size':10,'color':'Green'}
ax.set_xlabel('Outlet Location Type', fontdict=f2)
ax.set_ylabel('Total Sales', fontdict=f2)
ax.set_title('Fat content by outlet for total sales', fontdict=f1)
plt.legend(title='Item Fat Content',loc='upper left',framealpha=0.5,facecolor='#FCFCFC',edgecolor='#F9F9F8',fancybox=True,shadow=True)
plt.tight_layout()
plt.show()

# %%
Sales_by_outlocation_fatcontent=d.pivot_table(
    index='Outlet Location Type',
    columns='Item Fat Content',
    values='Sales',
    aggfunc='sum'
).reindex(columns=['Regular','Low Fat'])
ax=Sales_by_outlocation_fatcontent.plot(kind='bar',color=['green','yellow'])
plt.show()
